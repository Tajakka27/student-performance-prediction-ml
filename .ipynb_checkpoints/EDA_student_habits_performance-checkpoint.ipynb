# %% [markdown]
# <h1 style="font-size: 32px; color: #2c3e50;">🎓 Student Performance Analysis & Prediction</h1>
#
# <p style="font-size: 20 px;">    A machine learning project that analyzes student lifestyle, habits, and health factors to predict academic performance.</p>
#
# <hr>

# %% [markdown]
# <h2 style="font-size: 26px;">📌 Project Objectives</h2>
# <ul>
#   <li>Understand which factors impact student exam scores</li>
#   <li>Perform in-depth Exploratory Data Analysis (EDA)</li>
#   <li>Train regression models</li>
# </ul>

# %% [markdown]
# <center><h1> What is Exploratory Data Analysis? </h1></center>
#
# Exploratory Data Analysis (EDA) is a method of analyzing datasets to understand their main characteristics. It involves summarizing data features, detecting patterns, and uncovering relationships through visual and statistical techniques. EDA helps in gaining insights and formulating hypotheses for further analysis.

# %% [markdown]
# <center><h2>Step 1: Importing Libraries</h2></center>
#
# Import all the essential Python libraries.

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# <center><h2>Step 2: Loading the Dataset</h2></center>
#
# Read your dataset into a DataFrame using `pd.read_csv()` or the appropriate method.

# %%
# Load the dataset
df = pd.read_csv('student_habits_performance.csv')
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %% [markdown]
# <center><h2>Step 3: Understanding the Data</h2></center>
#
# Check the structure and get basic information.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %% [markdown]
# <center><h2>Step 4: Data Cleaning</h2></center>
#
# <h3>Check for missing values:<h3>

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %% [markdown]
# <h3>check for duplicates:<h3>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop('student_id', axis=1, inplace=True)

# %% [markdown]
# <center><h2>Step 4: Univariate Analysis<h2><center>

# %% [markdown]
# ## 📊 Univariate Analysis: Visualization Guide
#
#
# ### 🔠 For **Categorical Values**, we usually use:
# - **Bar Chart / Countplot** – to display frequency of each category.
# - **Pie Chart** – to show proportions (used less often in data analysis).
# - **Stacked Bar Chart** – to compare distributions between two categorical variables.
# - **Box/Violin Plots** (if comparing against a numeric variable) – to show spread of numeric data across categories.
#
#
# ### 🔢 For **Numerical Values**, we usually use:
# - **Histogram** – to show the distribution of values.
# - **Box Plot** – to detect outliers and see the spread.
# - **Violin Plot** – to visualize the distribution and density.
# - **CDF/PDF Plots** – to observe cumulative or probability distribution patterns.

# %% [markdown]
# <center><h2> Categorical Values </h2></center>

# %%
cat_cols = ['gender', 'part_time_job', 'diet_quality', 'parental_education_level', 
                   'internet_quality', 'extracurricular_participation']

for col in cat_cols:
    print(f"\n{col} :\n", df[col].value_counts())
# Out:
# gender :
#  Female    481
# Male      477
# Other      42
# Name: gender, dtype: int64
#
# part_time_job :
#  No     785
# Yes    215
# Name: part_time_job, dtype: int64
#
# diet_quality :
#  Fair    437
# Good    378
# Poor    185
# Name: diet_quality, dtype: int64
#
# parental_education_level :
#  High School    392
# Bachelor       350
# Master         167
# None            91
# Name: parental_education_level, dtype: int64
#
# internet_quality :
#  Good       447
# Average    391
# Poor       162
# Name: internet_quality, dtype: int64
#
# extracurricular_participation :
#  No     682
# Yes    318
# Name: extracurricular_participation, dtype: int64

# %% [markdown]
# # Bar charts for the categorical values
#
# We use bar charts to visualize the frequency of each category within the categorical features.
# This helps us understand the distribution of values and identify any class imbalance or dominant categories in the dataset.

# %%
plt.figure(figsize=(15, 6))

# Loop through the categorical columns to create subplots
for i, col in enumerate(cat_cols, 1):
    plt.subplot(2, 3, i)  
    sns.countplot(x=col, data=df)
    plt.title(f'Count Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# <center><h2> Pie Charts<h2> <center>

# %%
plt.figure(figsize=(15, 10))

# Loop through the categorical columns to create subplots
for i, col in enumerate(cat_cols, 1):
    plt.subplot(2, 3, i)  # Creating a 2x3 grid of subplots
    df[col].value_counts().plot.pie(
        autopct='%1.1f%%',
        startangle=90,
        colors=sns.color_palette("Set2"),
        wedgeprops={'edgecolor': 'white'}
    )
    plt.title(f'Pie Chart of {col}')
    plt.ylabel('')  # Hide y-axis label

# Auto-adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# <center> <h2> Gender vs Part-time Job <h2> </center>

# %%
cross_tab = pd.crosstab(df['gender'], df['part_time_job'])

cross_tab.plot(kind='bar', stacked=True, figsize=(8,6), colormap='viridis')
plt.title('Stacked Bar Chart: Gender vs Part-time Job')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Part-time Job')
plt.tight_layout()
plt.show()

# %% [markdown]
# <center> <h1> Numerical Values <h1> </center>

# %%
num_cols = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
               'attendance_percentage', 'sleep_hours', 'exercise_frequency',
               'mental_health_rating', 'exam_score']

# %% [markdown]
# # Histograms for the numerical values

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)  # Adjust the layout for 3 rows and 3 columns
    sns.histplot(df[col])  # Plot histogram with KDE
    plt.title(col)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Why is a Box Plot Important?
#
# <p>
# A <strong>box plot</strong> (or box-and-whisker plot) is a powerful visualization tool used to understand the distribution of numerical data. It is particularly useful for:
# </p>
#
# <ul>
#   <li> <strong>Identifying Outliers:</strong> Points that lie outside the whiskers (typically 1.5×IQR from Q1 or Q3) are outliers — values that may be errors or unusual cases worth further investigation.</li>
#   <li> <strong>Understanding Distribution:</strong> It shows the <em>median</em>, <em>quartiles</em>, and <em>spread</em> of the data at a glance. This helps understand if the data is symmetric, skewed, or contains any concentration in specific ranges.</li>
#   <li> <strong>Comparing Multiple Variables:</strong> When used across multiple features, box plots make it easy to compare variability and central tendency side-by-side.</li>
#   <li><strong>Detecting Skewness:</strong> If the median is not centered in the box or one whisker is longer, it suggests skewness in the data.</li>
# </ul>

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Violin plot for numerical columns

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)
    sns.violinplot(x=df[col])
    plt.title(f'Violin Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# # CDF Plot
# plt.figure(figsize=(15, 10))
# for i, col in enumerate(num_cols, 1):
#     plt.subplot(3, 3, i)
#     sns.ecdfplot(df[col])
#     plt.title(f'Cumulative Distribution Function (CDF) of {col}')
# plt.tight_layout()
# plt.show()

# # PDF Plot
# plt.figure(figsize=(15, 10))
# for i, col in enumerate(num_cols, 1):
#     plt.subplot(3, 3, i)
#     sns.histplot(df[col], kde=True)  # kde=True shows the probability density function
#     plt.title(f'Probability Density Function (PDF) of {col}')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# <center><h1> Step 5: Bivariate Analysis <h2></center>

# %% [markdown]
# ### Numerical vs Numerical:
# Use **scatter plots**, **correlation heatmaps**, or **joint plots** to explore the relationship between two numerical variables.
#
# ### Numerical vs Categorical:
# Use **box plots**, **violin plots**, **bar plots**, or **point plots** to examine the distribution and comparison of a numerical variable across different categories of a categorical variable.
#
# ### Categorical vs Categorical:
# Use **stacked bar charts** or **grouped bar charts** to visualize the relationship between two categorical variables by showing counts or proportions.
#
# ### When You Need to Observe Relationship Using Probability Distribution:
#
# **Joint Plot**: Combines scatter plot, histogram, and kernel density estimation (KDE) to show relationships between two variables. It helps to visualize the relationship between numerical variables while showing their individual distributions.
#
# **Pair Plot**: Displays scatter plots and histograms for every pair of variables in the dataset, allowing you to observe relationships for multiple variable combinations at once. It is a useful tool to examine how different variables interact and understand overall data patterns.

# %% [markdown]
# # Plotting scatter plots for numerical columns vs exam_score

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)
    sns.scatterplot(x=df[col], y=df['exam_score'])
    plt.title(f'{col} vs Exam Score')
    plt.xlabel(col)
    plt.ylabel('Exam Score')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting box plot plots for categorical columns vs exam_score

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(cat_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col], y=df['exam_score'])
    plt.title(f'{col} vs Exam Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plotting plot plots for categorical columns vs exam_score

# %%
# Point plot for categorical columns vs exam_score
plt.figure(figsize=(15, 10))
for i, col in enumerate(cat_cols, 1):
    plt.subplot(2, 3, i)
    sns.pointplot(x=df[col], y=df['exam_score'], estimator='mean', ci=None)
    plt.title(f'{col} vs Exam Score')

# %% [markdown]
# <center><h2> Step 6: Multivariate Analysis </h2></center>
# <br>
# Multivariate analysis helps uncover interactions between **three or more variables** at once. It provides a deeper understanding of complex relationships in the dataset.

# %% [markdown]
# ## ✅ 1. Heatmap (Correlation Matrix)
# - **Purpose**: Understand relationships between multiple numerical variables.
# - **Use case**: Identify which variables are most correlated with the target (`exam_score`).
# - **Tool**: `sns.heatmap()`

# %%
# Compute the correlation matrix
corr = df[num_cols].corr()
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=1, square=True)
plt.title('Correlation Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ 2. Pair Plot
# - **Purpose**: Visualize relationships across multiple pairs of numerical variables simultaneously.
# - **Use case**: Spot trends, clusters, or outliers involving `exam_score`, `study_hours`, `sleep_hours`, etc.
# - **Tool**: `sns.pairplot(df[num_cols])`

# %%
g = sns.FacetGrid(df, col='gender', row='part_time_job')
g.map(sns.scatterplot, 'study_hours_per_day', 'exam_score')

# %% [markdown]
# # Performance Drivers:
#
#
# ## Study Hours vs Exam Score

# %%
sns.scatterplot(data=df, x='study_hours_per_day', y='exam_score', hue='gender')
plt.title('Study Hours vs Exam Score')
plt.show()

# %% [markdown]
# # Study Hours vs Exam Score with Regression Line

# %%
plt.figure(figsize=(10, 6))
sns.lmplot(data=df, x='study_hours_per_day', y='exam_score', hue='gender', aspect=1.5, ci=None)
plt.title('Study Hours vs Exam Score with Regression Line')
plt.show()

# %% [markdown]
# <center><h2> Step 7: Data Preprocessing </h2></center>

# %% [markdown]
# <h2> Encoding Categorical Variables</h2>
#
# <p>
# To prepare the dataset for machine learning models, we performed encoding on the categorical variables. Machine learning algorithms typically require numerical input, so converting categorical variables into a numerical format is a necessary preprocessing step.
# </p>
#
# <h3> Label Encoding</h3>
# <p>
# We applied <strong>Label Encoding</strong> to ordinal categorical features where the categories have an inherent order:
# </p>
# <ul>
#   <li><code>diet_quality</code></li>
#   <li><code>parental_education_level</code></li>
#   <li><code>internet_quality</code></li>
# </ul>
# <p>
# Label Encoding converts each category into a corresponding integer value. For example, "Poor", "Fair", and "Good" may be converted to 0, 1, and 2 respectively.
# </p>
#
# <h3> One-Hot Encoding</h3>
# <p>
# For nominal categorical features that have no ordinal relationship, we used <strong>One-Hot Encoding</strong>:
# </p>
# <ul>
#   <li><code>gender</code></li>
#   <li><code>part_time_job</code></li>
#   <li><code>extracurricular_participation</code></li>
# </ul>
# <p>
# This process creates binary columns for each category, avoiding any ordinal misinterpretation. We used
# </p>

# %%
from sklearn.preprocessing import LabelEncoder

# Make a copy to avoid modifying original
df_encoded = df.copy()

# Label Encoding
label_cols = ['diet_quality', 'parental_education_level', 'internet_quality']
le = LabelEncoder()
for col in label_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col])

# One-Hot Encoding
one_hot_cols = ['gender', 'part_time_job', 'extracurricular_participation']
df_encoded = pd.get_dummies(df_encoded, columns=one_hot_cols, drop_first=True)

# Display the first few rows of the encoded dataframe
df_encoded.head()
# Out:
#    age  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23                  0.0                 1.2            1.1
# 1   20                  6.9                 2.8            2.3
# 2   21                  1.4                 3.1            1.3
# 3   23                  1.0                 3.9            1.0
# 4   19                  5.0                 4.4            0.5
#
#    attendance_percentage  sleep_hours  diet_quality  exercise_frequency  \
# 0                   85.0          8.0             0                   6
# 1                   97.3          4.6             1                   6
# 2                   94.8          8.0             2                   1
# 3                   71.0          9.2             2                   4
# 4                   90.9          4.9             0                   3
#
#    parental_education_level  internet_quality  mental_health_rating  \
# 0                         2                 0                     8
# ...

# %% [markdown]
# # Seperating the X and Y feature

# %%
X = df_encoded.drop('exam_score', axis=1)
y = df_encoded['exam_score']
print(X.shape, y.shape)
# Out:
# (1000, 15) (1000,)

# %% [markdown]
# <h2> Feature Scaling: Standardization with StandardScaler</h2>
#
# <p>
# Feature scaling is a crucial step in data preprocessing, especially for machine learning algorithms that are sensitive to the scale of input features (e.g., Logistic Regression, KNN, SVM).
# </p>
#
# <p>
# In this step, we applied <strong>StandardScaler</strong> from <code>sklearn.preprocessing</code> to normalize the dataset. StandardScaler standardizes features by removing the mean and scaling to unit variance (i.e., it transforms the data to have zero mean and a standard deviation of one).
# </p>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled.shape  # this will show the shape after scaling
# Out:
# (1000, 15)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# <h2> Model Training and Evaluation: Linear Regression</h2>
#
# <p>
# In this step, we trained a <strong>Linear Regression</strong> model to predict the target variable using the training dataset. Linear Regression is a fundamental algorithm used for modeling the relationship between one or more independent variables and a continuous dependent variable.
# </p>

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
model.score(X_test, y_test)
# Out:
# 0.8969620362982048

# %%
X.columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'gender_Male', 'gender_Other',
#        'part_time_job_Yes', 'extracurricular_participation_Yes'],
#       dtype='object')

# %% [markdown]
# # Top 10 Important Features:

# %%
feature_names = (['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'diet_quality',
       'exercise_frequency', 'parental_education_level', 'internet_quality',
       'mental_health_rating', 'gender_Male', 'gender_Other',
       'part_time_job_Yes', 'extracurricular_participation_Yes'])                 
                 
top_10_indices = np.argsort(np.abs(importance))[-10:]

# Create a DataFrame with the feature names and their importance
top_10_features = pd.DataFrame({
    'Feature': np.array(feature_names)[top_10_indices],
    'importance': importance[top_10_indices]
}).sort_values(by='importance', ascending=False).reset_index(drop=True)

# Display the top 10 features with importance
print("Top 10 Important Features:")
print(top_10_features)
# Out:
# Top 10 Important Features:
#                     Feature  importance
# 0       study_hours_per_day   13.983963
# 1      mental_health_rating    5.554490
# 2        exercise_frequency    2.668511
# 3               sleep_hours    2.438072
# 4     attendance_percentage    1.386131
# 5              gender_Other    0.160256
# 6  parental_education_level   -0.282377
# 7              diet_quality   -0.290413
# 8             netflix_hours   -2.497929
# 9        social_media_hours   -3.157236

# %% [markdown]
# # Trying other models to see which model performs the best

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Try multiple models
models = {
    "Linear": LinearRegression(),
    "Ridge": Ridge(alpha=1.0),
    "Lasso": Lasso(alpha=0.1),
    "Random Forest": RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)
}

regression_metrics = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    regression_metrics[name] = {'R²': r2, 'RMSE': rmse}
    
metrics_df = pd.DataFrame(regression_metrics).T

# Display the DataFrame
print(metrics_df)
# Out:
#                      R²      RMSE
# Linear         0.896962  5.140227
# Ridge          0.896906  5.141621
# Lasso          0.897386  5.129642
# Random Forest  0.809784  6.984040

# %%
metrics_df.plot(kind='bar', figsize=(10, 6), color=['Red', 'Blue'])
plt.title('Regression Model Comparison (R² and RMSE)')
plt.ylabel('Score')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model Evaluation: R² (R-squared) and RMSE (Root Mean Squared Error)
#
# To determine which model is the best, I focused on both **R² (R-squared)** and **RMSE (Root Mean Squared Error)**, which are both important metrics for evaluating regression models:
#
# - **R² (R-squared)**: This indicates how well the model's predictions match the actual data. A value closer to 1 suggests a better fit. From your results:
#   - The **Lasso** model has the highest R² (0.897386), indicating it explains the most variance in the data.
#
# - **RMSE (Root Mean Squared Error)**: This measures the average magnitude of the errors between predicted and actual values. A lower RMSE indicates better performance, as it means the model’s predictions are closer to the true values. From your results:
#   - **Lasso** also has the lowest RMSE (5.129642), meaning it makes the smallest prediction errors.
#
# ### Conclusion:
# **Lasso** is the best model here because:
# - It has the highest R² (indicating it explains the most variance in the data).
# - It has the lowest RMSE (indicating it makes the smallest prediction errors).
